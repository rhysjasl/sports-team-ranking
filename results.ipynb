# %% [markdown]
# # Sports Team Ranking
# ## Compile Results
# This notebook is used to process all the data files and display the final rankings. <br/>
# <br/>
# Originally coded by Rhys-Jasper León <br/>
# Last updated 2025 November 18

# %%
# import libraries
import numpy as np
import pandas as pd
import numpy.linalg as la

# import processing and analysis functions
from processing import import_league_data
from analysis import create_ranking

# %%
# set verbose mode
verbose = False

# %% [markdown]
# ## MLB

# %%
# file names
mlb_filename = 'data/mlb_2025_season.csv'
mlb_teams = 'data/mlb_teams.csv'
mlb_save = 'results/mlb_ranking_2025' # don't include file extension

# %%
# import MLB data
mlb_df, *_ = import_league_data(mlb_filename, verbose=verbose)

# create MLB ranking
mlb_ranking = create_ranking(mlb_teams, mlb_df, verbose=verbose)
# mlb_ranking = create_ranking(mlb_teams, mlb_df, verbose=verbose, save_file=mlb_save, save_type='csv')
# Out:
# Nonlinear method converged after 5 iterations.
# <style type="text/css">
# </style>
# <table id="T_5b0ba">
#   <thead>
#     <tr>
#       <th id="T_5b0ba_level0_col0" class="col_heading level0 col0" >Team</th>
#       <th id="T_5b0ba_level0_col1" class="col_heading level0 col1" >Wins</th>
#       <th id="T_5b0ba_level0_col2" class="col_heading level0 col2" >Wins Rank</th>
#       <th id="T_5b0ba_level0_col3" class="col_heading level0 col3" >Direct Rank</th>
#       <th id="T_5b0ba_level0_col4" class="col_heading level0 col4" >Nonlinear Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5b0ba_row0_col0" class="data row0 col0" >Milwaukee Brewers</td>
#       <td id="T_5b0ba_row0_col1" class="data row0 col1" >97</td>
#       <td id="T_5b0ba_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_5b0ba_row0_col3" class="data row0 col3" >3</td>
#       <td id="T_5b0ba_row0_col4" class="data row0 col4" >2</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ## NBA

# %%
# file names
nba_filename = 'data/nba_2024_2025_season.csv'
nba_teams = 'data/nba_teams.csv'
nba_save = 'results/nba_ranking_2025' # don't include file extension

# %%
# import NBA data
nba_df, *_ = import_league_data(nba_filename, verbose=verbose)

# create NBA ranking
nba_ranking = create_ranking(nba_teams, nba_df, verbose=verbose)
# nba_ranking = create_ranking(nba_teams, nba_df, verbose=verbose, save_file=nba_save, save_type='csv')
# Out:
# Nonlinear method converged after 6 iterations.
# <style type="text/css">
# </style>
# <table id="T_44d98">
#   <thead>
#     <tr>
#       <th id="T_44d98_level0_col0" class="col_heading level0 col0" >Team</th>
#       <th id="T_44d98_level0_col1" class="col_heading level0 col1" >Wins</th>
#       <th id="T_44d98_level0_col2" class="col_heading level0 col2" >Wins Rank</th>
#       <th id="T_44d98_level0_col3" class="col_heading level0 col3" >Direct Rank</th>
#       <th id="T_44d98_level0_col4" class="col_heading level0 col4" >Nonlinear Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_44d98_row0_col0" class="data row0 col0" >Oklahoma City Thunder</td>
#       <td id="T_44d98_row0_col1" class="data row0 col1" >68</td>
#       <td id="T_44d98_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_44d98_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_44d98_row0_col4" class="data row0 col4" >1</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# ## NFL

# %%
# file names
nfl_filename = 'data/nfl_2024_2025_season.csv'
nfl_teams = 'data/nfl_teams.csv'
nfl_save = 'results/nfl_ranking_2025' # don't include file extension

# %%
# import NFL data
nfl_df, *_ = import_league_data(nfl_filename, verbose=verbose)

# create NFL ranking
nfl_ranking = create_ranking(nfl_teams, nfl_df, verbose=verbose)
# nfl_ranking = create_ranking(nfl_teams, nfl_df, verbose=verbose, save_file=nfl_save, save_type='csv')
# Out:
# Nonlinear method converged after 11 iterations.
# <style type="text/css">
# </style>
# <table id="T_c7bb8">
#   <thead>
#     <tr>
#       <th id="T_c7bb8_level0_col0" class="col_heading level0 col0" >Team</th>
#       <th id="T_c7bb8_level0_col1" class="col_heading level0 col1" >Wins</th>
#       <th id="T_c7bb8_level0_col2" class="col_heading level0 col2" >Wins Rank</th>
#       <th id="T_c7bb8_level0_col3" class="col_heading level0 col3" >Direct Rank</th>
#       <th id="T_c7bb8_level0_col4" class="col_heading level0 col4" >Nonlinear Rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_c7bb8_row0_col0" class="data row0 col0" >Detroit Lions</td>
#       <td id="T_c7bb8_row0_col1" class="data row0 col1" >15</td>
#       <td id="T_c7bb8_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_c7bb8_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_c7bb8_row0_col4" class="data row0 col4" >3</td>
#     </tr>
#     <tr>
# ...
